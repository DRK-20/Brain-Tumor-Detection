# %% [markdown]
# # Brain Tumor Detection

# %% [markdown]
# ## Importing Libraries

# %%
# Libraries Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Libraries for Data Pre-Processing
import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image, ImageEnhance

# Libraries for Model Creation
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.losses import *
from tensorflow.keras.models import *
from tensorflow.keras.metrics import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.applications import *
from tensorflow.keras.preprocessing.image import load_img

# General Purpose Libraries
from tqdm import tqdm
import os
import random

print('Libraries imported successfully!')
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## Paths of Dataset

# %%
# Paths
train_dir = r'/kaggle/input/brain-tumor-mri-dataset/Training'
test_dir = '/kaggle/input/brain-tumor-mri-dataset/Testing'

# %% [markdown]
# ## Storing Training Data Info

# %%
# Training Set
train_paths = []
train_labels = []

for label in os.listdir(train_dir):
    for image in os.listdir(train_dir + '//' + label):
        train_paths.append(train_dir + '//' + label + '//' + image)
        train_labels.append(label)

train_paths, train_labels = shuffle(train_paths, train_labels)
print('Training set setup complete!')
# Out:
# Training set setup complete!

# %% [markdown]
# ## Storing Validation & Testing Data Info

# %%
# Testing & Validation Set Split
validation_ratio = 0.5

test_paths = []
test_labels = []
validation_paths = []
validation_labels = []

for label in os.listdir(test_dir):
    label_dir = test_dir + '//' + label
    images = os.listdir(label_dir)
    random.shuffle(images)

    num_validation = int(len(images) * validation_ratio)

    validation_images = images[:num_validation]
    testing_images = images[num_validation:]

    validation_paths.extend([label_dir + '//' + img for img in validation_images])
    validation_labels.extend([label] * len(validation_images))
    test_paths.extend([label_dir + '//' + img for img in testing_images])
    test_labels.extend([label] * len(testing_images))

validation_data = list(zip(validation_paths, validation_labels))
random.shuffle(validation_data)
validation_paths, validation_labels = zip(*validation_data)

test_data = list(zip(test_paths, test_labels))
random.shuffle(test_data)
test_paths, test_labels = zip(*test_data)

print('Testing & validation sets\' setup complete!')
# Out:
# Testing & validation sets' setup complete!

# %% [markdown]
# ## Dataset Split Analysis

# %%
# Train-Validation-Test Split Analysis
plt.figure(figsize = (14, 6))
colours = ['Orange', 'Blue', 'Green']
plt.rcParams.update({'font.size': 14})
plt.pie([len(train_labels), len(test_labels), len(validation_labels)],
        labels = ['Training Set', 'Testing Set', 'Validation Set'],
        colors = colours, autopct = '%.1f%%', explode = (0.06, 0.06, 0.06),
        startangle = 30);

# %% [markdown]
# ## Classes/Labels Analysis

# %%
# Label Analysis of Dataset
plt.figure(figsize = (10, 10))
colours = ['Orange', 'Green', 'Red', 'Blue']
plt.pie([len(os.listdir(train_dir + '//' + label)) 
        for label in os.listdir(train_dir)],
        labels = os.listdir(train_dir),
        colors = colours,
        explode = (0.08, 0.08, 0.08, 0.08),
        autopct = '%1.1f%%')
plt.show()

# %% [markdown]
# ## Image Enhancement

# %%
# Image Augmentation & Enhancement
def augment_image(image):
    image = Image.fromarray(np.uint8(image))
    image = ImageEnhance.Brightness(image).enhance(random.uniform(0.9, 1.3))
    image = ImageEnhance.Contrast(image).enhance(random.uniform(0.9, 1.3))
    image = ImageEnhance.Sharpness(image).enhance(random.uniform(0.9, 1.3))
    image = np.array(image) / 255.0
    return image

print('Image enhancement setup complete!')
# Out:
# Image enhancement setup complete!

# %% [markdown]
# ## Sample Data

# %%
# Data Samples
IMAGE_SIZE = 128

def open_images(paths):
    images = []
    
    for path in paths:
        image = load_img(path, target_size = (IMAGE_SIZE, IMAGE_SIZE))
        image = augment_image(image)
        images.append(image)
        
    return np.array(images)

images = open_images(train_paths[50:59])
labels = train_labels[50:59]
fig = plt.figure(figsize = (12, 6))

for x in range(1, 9):
    fig.add_subplot(2, 4, x)
    plt.axis('off')
    plt.title(labels[x])
    plt.imshow(images[x])
    
plt.rcParams.update({'font.size': 12})
plt.show()

# %% [markdown]
# ## Image Generation

# %%
# Data Generator
unique_labels = os.listdir(train_dir)

def encode_label(labels):
    encoded = []
    
    for x in labels:
        encoded.append(unique_labels.index(x))
        
    return np.array(encoded)

def decode_label(labels):
    decoded = []
    
    for x in labels:
        decoded.append(unique_labels[x])
        
    return np.array(decoded)

def datagen(paths, labels, batch_size = 12, epochs = 1):
    for _ in range(epochs):
        for x in range(0, len(paths), batch_size):
            batch_paths = paths[x: x + batch_size]
            batch_images = open_images(batch_paths)
            batch_labels = labels[x: x + batch_size]
            batch_labels = encode_label(batch_labels)
            yield batch_images, batch_labels
            
print('Data generator setup complete!')
# Out:
# Data generator setup complete!

# %% [markdown]
# ## CNN Model Creation

# %%
# Model Creation
def build_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation = 'relu', input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(Flatten())
    model.add(Dense(16, activation = 'relu'))
    model.add(Dense(4, activation = 'softmax'))
    model.compile(optimizer = 'adam', 
                  loss = 'sparse_categorical_crossentropy', 
                  metrics = ['accuracy'])
    return model

model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 64)        73792
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 32)          18464
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 16)                8208
#
#  dense_1 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 193,780
# Trainable params: 193,780
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Neural Network Diagram

# %%
# Model Picturization
keras.utils.plot_model(model, show_shapes = True)

# %% [markdown]
# ## Model Training

# %%
model_info = model.fit(
    datagen(
        train_paths, 
        train_labels, 
        batch_size = 32, 
        epochs = 20
    ), 
    steps_per_epoch = len(train_paths) // 32, 
    validation_data = datagen(
        validation_paths, 
        validation_labels, 
        batch_size = 12, 
        epochs = 20
    ),
    validation_steps = len(validation_paths) // 12,
    epochs = 20
)

print('Training complete!')
# Out:
# Epoch 1/20
# 178/178 [==============================] - 113s 627ms/step - loss: 0.8186 - accuracy: 0.6557 - val_loss: 0.7158 - val_accuracy: 0.6836
# Epoch 2/20
# 178/178 [==============================] - 106s 596ms/step - loss: 0.4903 - accuracy: 0.8123 - val_loss: 0.5186 - val_accuracy: 0.7870
# Epoch 3/20
# 178/178 [==============================] - 110s 617ms/step - loss: 0.3653 - accuracy: 0.8553 - val_loss: 0.4788 - val_accuracy: 0.8025
# Epoch 4/20
# 178/178 [==============================] - 109s 613ms/step - loss: 0.3055 - accuracy: 0.8901 - val_loss: 0.4116 - val_accuracy: 0.8302
# Epoch 5/20
# 178/178 [==============================] - 110s 616ms/step - loss: 0.2350 - accuracy: 0.9167 - val_loss: 0.4088 - val_accuracy: 0.8549
# Epoch 6/20
# 178/178 [==============================] - 110s 620ms/step - loss: 0.2095 - accuracy: 0.9236 - val_loss: 0.3037 - val_accuracy: 0.8873
# Epoch 7/20
# 178/178 [==============================] - 110s 619ms/step - loss: 0.1531 - accuracy: 0.9444 - val_loss: 0.2333 - val_accuracy: 0.9136
# Epoch 8/20
# 178/178 [==============================] - 107s 602ms/step - loss: 0.1208 - accuracy: 0.9592 - val_loss: 0.2118 - val_accuracy: 0.9275
# Epoch 9/20
# 178/178 [==============================] - 108s 606ms/step - loss: 0.1052 - accuracy: 0.9606 - val_loss: 0.3215 - val_accuracy: 0.9012
# Epoch 10/20
# 178/178 [==============================] - 107s 600ms/step - loss: 0.0867 - accuracy: 0.9697 - val_loss: 0.2601 - val_accuracy: 0.9259
# Epoch 11/20
# 178/178 [==============================] - 110s 619ms/step - loss: 0.0880 - accuracy: 0.9688 - val_loss: 0.2521 - val_accuracy: 0.9182
# Epoch 12/20
# 178/178 [==============================] - 112s 627ms/step - loss: 0.0860 - accuracy: 0.9687 - val_loss: 0.2163 - val_accuracy: 0.9244
# Epoch 13/20
# 178/178 [==============================] - 111s 623ms/step - loss: 0.0587 - accuracy: 0.9794 - val_loss: 0.1726 - val_accuracy: 0.9444
# Epoch 14/20
# 178/178 [==============================] - 112s 627ms/step - loss: 0.0544 - accuracy: 0.9810 - val_loss: 0.2968 - val_accuracy: 0.9213
# Epoch 15/20
# 178/178 [==============================] - 111s 621ms/step - loss: 0.0653 - accuracy: 0.9764 - val_loss: 0.3168 - val_accuracy: 0.9321
# Epoch 16/20
# 178/178 [==============================] - 111s 624ms/step - loss: 0.0431 - accuracy: 0.9861 - val_loss: 0.2142 - val_accuracy: 0.9475
# Epoch 17/20
# 178/178 [==============================] - 111s 625ms/step - loss: 0.0372 - accuracy: 0.9863 - val_loss: 0.2221 - val_accuracy: 0.9414
# Epoch 18/20
# 178/178 [==============================] - 110s 620ms/step - loss: 0.0275 - accuracy: 0.9901 - val_loss: 0.1984 - val_accuracy: 0.9552
# Epoch 19/20
# 178/178 [==============================] - 111s 623ms/step - loss: 0.0302 - accuracy: 0.9893 - val_loss: 0.1570 - val_accuracy: 0.9614
# Epoch 20/20
# 178/178 [==============================] - 111s 625ms/step - loss: 0.0295 - accuracy: 0.9907 - val_loss: 0.2583 - val_accuracy: 0.9367
# Training complete!

# %% [markdown]
# ## Train Validation Curve

# %%
# Train-Validation Accuracy Curve
plt.figure(figsize = (20, 15))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(model_info.history['accuracy'], color = 'b', label = "Training Accuracy")
plt.plot(model_info.history['val_accuracy'], color = 'r', label = "Validation Accuracy")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Model Evaluation

# %%
# Model Evaluation
train_loss, train_acc = model.evaluate(open_images(train_paths), encode_label(train_labels))
test_loss, test_acc = model.evaluate(open_images(test_paths), encode_label(test_labels))

print(f'''\nTraining Evaluation:-
\t> Train Accuracy: {train_acc}
\t> Train Loss: {train_loss}
\nTesting Evaluation:-
\t> Testing Accuracy: {test_acc}
\t> Testing Loss: {test_loss}''')
# Out:
# 179/179 [==============================] - 27s 150ms/step - loss: 0.0610 - accuracy: 0.9818
# 21/21 [==============================] - 3s 147ms/step - loss: 0.3344 - accuracy: 0.9299
#
# Training Evaluation:-
# 	> Train Accuracy: 0.981792688369751
# 	> Train Loss: 0.06099843606352806
#
# Testing Evaluation:-
# 	> Testing Accuracy: 0.9298780560493469
# 	> Testing Loss: 0.334417462348938

# %% [markdown]
# ## Prediction

# %%
# Prediction Report
prediction = model.predict(open_images(test_paths))
prediction = np.argmax(prediction, axis = 1)
print(classification_report(encode_label(test_labels), prediction, target_names = unique_labels))
# Out:
# 21/21 [==============================] - 3s 149ms/step
#               precision    recall  f1-score   support
#
#    pituitary       0.88      1.00      0.94       150
#      notumor       0.97      1.00      0.98       203
#   meningioma       0.91      0.81      0.86       153
#       glioma       0.92      0.87      0.89       150
#
#     accuracy                           0.92       656
#    macro avg       0.92      0.92      0.92       656
# weighted avg       0.92      0.92      0.92       656

# %% [markdown]
# ## Saving Model

# %%
model.save_weights('/kaggle/working/model.hdf5')
